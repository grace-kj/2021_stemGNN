# %%
cd '/content/drive/MyDrive/Colab Notebooks/건축실무/StemGNN-master'
# Out:
# /content/drive/MyDrive/Colab Notebooks/건축실무/StemGNN-master

# %%
pip install -r requirements.txt

# %%
#!python3 main.py --train True --evaluate True --dataset ECG_data --output_dir "/content/drive/MyDrive/Colab_Notebooks/건축실무" --n_route 140 --window_size 12 --horizon 3 --norm_method z_score --train_length 7 --validate_length 2 --test_length 1
# Out:
# python3: can't open file 'main.py': [Errno 2] No such file or directory

# %%
# !python main.py --train True --evaluate True --dataset road_nodes2 --window_size 2 --epoch 10 --horizon 1 --lr 0.0005 --norm_method z_score --train_length 9 --valid_length 3 --test_length 4
# Out:
# Training configs: Namespace(batch_size=32, dataset='road_nodes2', decay_rate=0.5, device='cpu', dropout_rate=0.5, early_stop=False, epoch=10, evaluate=True, exponential_decay_step=5, horizon=1, leakyrelu_rate=0.2, lr=0.0005, multi_layer=5, norm_method='z_score', optimizer='RMSProp', test_length=4.0, train=True, train_length=9.0, valid_length=3.0, validate_freq=1, window_size=2)
# 9 3 4
# Total Trainable Params: 2245572
# /content/drive/MyDrive/Colab Notebooks/건축실무/StemGNN-master/models/base_model.py:49: UserWarning: The function torch.rfft is deprecated and will be removed in a future PyTorch release. Use the new torch.fft module functions, instead, by importing torch.fft and calling torch.fft.fft or torch.fft.rfft. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:590.)
#   ffted = torch.rfft(input, 1, onesided=False)
# ...
